# %% [markdown]
# <a href="https://colab.research.google.com/github/keshav123333/Machine_learning_100_campusx/blob/main/roc_auc/roc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Roc Curve
#
#
# it helps to make a informed decision of threshold value jisse hum apna sahi threshold chun sake and uss threshold ko use karke decision bana sake

# %% [markdown]
# #confusion matrix

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #true positive rate
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ye batat ki kitne postive mein se kitne positve hum guess kar paye

# %% [markdown]
# #false postoive rate
#
# isse kam karte so apne kitne not spam ko spam bata diya

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Roc curve
#
# isme tpr and fpr ke bich graph banta usko hi roc curve
#
# so aap har threshold ko try karte and uss hisab se aap confusion matrix bante and tpr and fpr curve banate

# %% [markdown]
# different cases ko video se dekh sakt ho

# %%
#dusri notebook dekh for code
