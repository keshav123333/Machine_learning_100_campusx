# %% [markdown]
# <a href="https://colab.research.google.com/github/keshav123333/Machine_learning_100_campusx/blob/main/Kmean_cluster/Kmean_cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #kmean custer

# %% [markdown]
# 1. kmean mein hum cluster rakte then har point se dist jo point jiss cluster se pass usse vo assign then sare cluster ka centroid find karte and humare cluster ko update karte then vapis se sare cluster ka sare pt se dist and ye jab tak jab tak changes band ni ho jaate means ha ho gaya
#
#
# 2. elbow curve bata ki kitne cluster ya no. of cluster hum lenge
#
# wcss -> video dekh le dusra usme hai ye hota like maan 2 cluster so unko assign pt se un cluster ki d^2+d2^2... aise niklate and aur bas plus iska video dekh le
#
# ye no. of cluster badne pe kam hota hai

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/refs/heads/main/kmeans/student_clustering.csv")

# %%
from sklearn.cluster import KMeans

# %%
plt.scatter(x=df["cgpa"],y=df["iq"])

# %%
wcss=[]

for i in range(1,11):
  kn=KMeans(n_clusters=i)
  kn.fit(df)

  wcss.append(kn.inertia_)

# %%
plt.plot(range(1,11),wcss)
#elbow at 4 so n_cluster=4

# %%
kn=KMeans(n_clusters=4)
kn.fit(df)
ypred=kn.predict(df)

# %%
ypred
# Out:
# array([3, 2, 1, 1, 2, 2, 1, 0, 2, 1, 3, 2, 1, 3, 2, 1, 2, 1, 2, 2, 1, 3,
#        1, 3, 3, 1, 3, 0, 1, 2, 0, 2, 0, 2, 1, 1, 0, 2, 3, 2, 3, 1, 1, 3,
#        0, 0, 1, 2, 0, 2, 3, 3, 0, 1, 0, 2, 2, 0, 2, 0, 2, 1, 1, 0, 3, 0,
#        1, 3, 2, 1, 2, 0, 1, 3, 2, 0, 2, 0, 3, 1, 1, 0, 2, 3, 0, 3, 0, 2,
#        0, 2, 0, 0, 1, 3, 1, 1, 0, 1, 3, 0, 2, 3, 3, 0, 3, 3, 1, 3, 0, 0,
#        1, 0, 2, 2, 1, 0, 1, 2, 0, 3, 3, 2, 1, 0, 1, 3, 1, 2, 3, 1, 1, 2,
#        3, 3, 2, 0, 2, 3, 1, 1, 1, 3, 2, 3, 3, 0, 3, 0, 2, 3, 0, 3, 0, 0,
#        3, 1, 2, 0, 2, 1, 3, 0, 2, 1, 0, 3, 2, 3, 3, 0, 0, 2, 0, 3, 3, 1,
#        0, 2, 3, 0, 0, 2, 2, 2, 1, 3, 1, 1, 0, 2, 1, 1, 3, 3, 1, 3, 0, 2,
#        2, 0], dtype=int32)

# %%
df[ypred==0].iloc[:,0]
# Out:
# 7      8.80
# 27     9.18
# 30     8.86
# 32     8.83
# 36     8.56
# 44     8.96
# 45     8.78
# 48     8.45
# 52     8.79
# 54     8.81
# 57     8.88
# 59     9.07
# 63     8.92
# 65     8.75
# 71     8.71
# 75     8.86
# 77     9.30
# 81     9.01
# 84     8.97
# 86     9.00
# 88     8.76
# 90     8.78
# 91     9.23
# 96     9.03
# 99     9.13
# 103    8.91
# 108    8.98
# 109    9.03
# 111    8.86
# 115    8.89
# 118    8.97
# 123    8.72
# 135    8.93
# 145    8.58
# 147    8.94
# 150    8.60
# 152    8.77
# 153    8.81
# 157    8.54
# 161    8.97
# 164    8.91
# 169    8.68
# 170    9.06
# 172    8.90
# 176    8.94
# 179    8.91
# 180    8.91
# 188    8.95
# 196    8.57
# 199    8.82
# Name: cgpa, dtype: float64

# %%
plt.scatter(df[ypred==0].iloc[:,0],df[ypred==0].iloc[:,1],c="red")
plt.scatter(df[ypred==1].iloc[:,0],df[ypred==1].iloc[:,1],c="blue")
plt.scatter(df[ypred==2].iloc[:,0],df[ypred==2].iloc[:,1],c="green")
plt.scatter(df[ypred==3].iloc[:,0],df[ypred==3].iloc[:,1],c="orange")

# %%
if np.all([1,2,3,4]==[1,2,3,4]):
  print("true")
# Out:
# true
