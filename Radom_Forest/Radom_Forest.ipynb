# %% [markdown]
# <a href="https://colab.research.google.com/github/keshav123333/Machine_learning_100_campusx/blob/main/Radom_Forest/Radom_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Random forest

# %% [markdown]
# forest pf tree
# ml main  problem ki high var. so
# descision tree banate ye hume high var low bias model dete so hum isse group kar dete and now data bat gaya so ko ek model sare pts pe overfit ni kar sakta and coleective descion ayega so
#
#
# ye humari main prblem solve hume ek low bias low var model de deta
#
#
#
# imp -: if kahi bhi high var ki dikkat use random forest or ensemble tecnique as they work good with high var. model and reduce is var.

# %% [markdown]
# bagging mein aap koi bhi model de dete ho
#
# bagging with decision tree bhi random forest se alag hota hai

# %% [markdown]
# bagging mein maan le 5 feature so hum ek descion tree ko random 2 col select and fir pure tree ko un do col pe hi train whereas
#
# Random forest mein hum har split maan ek tree ban rha so uski root node ke liye random ek col slect and then dusri node ke liye dusra col slect and aise randomeness jayada aati and overfitting km hoti hai

# %% [markdown]
# #Hyperparameter
#
# num estimator -kitne descion tree train
#
# max_feature-> kitne col se chun ke banaoge aap
# ye default auto rehta chao toh "sqrt" aise bhi de sakte ho
#
# bootstrap-> randomly slect karoge kya  true dete isse
# max_sample -> 0.5 0.75 dete hai ki kitni rows lenge ek baar mein ek tree ko train karne m
#
# max_depth
#
# iske aur bhi caht gpt kar le

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestClassifier(max_samples=0.75,oob_score=True)#direct hi apne datset p laga le

#oob mein humare kuch row kabhi use ni hote so un row pe hum test kar lete hai

# %% [markdown]
# grid cv use kar hyperparmeter
#
# gridcv(rf,param_grid=p,cv=5)
#
# yaha pe cv =5 means maan ek random forest train then usko har comb ke liye 5 model ttrain hota with diff train test split and then unke liye hum vo comn chunte jisne iss cv mein acha perform kiya hai

# %% [markdown]
# #feature importance
#
#
# ye bata ki kaunse feture more imp hai and kanse ni ye random forest detect kar sakta jab tu fit kar deta toh model.feature_importance_ ye likh toh vo de dega kaunse feature imp more building model mein ye feature imp hai
#
# ye har col ke liye ek no. deti jo uss row ka imp bata isse descion tree m bhi kar sakte hai
#
# iske liye video dekh le feture imp using random forest  imp hai maths and sab chezz ka and example code bhi diya haib

# %%
rf.feature_importance_

rf[0].feature_importance_ #ye bhi kar sakta hai tu if random forest ke pehle tree ka imp chaiye toh
