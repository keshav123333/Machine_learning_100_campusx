# %% [markdown]
# <a href="https://colab.research.google.com/github/keshav123333/Machine_learning_100_campusx/blob/main/regression_rmse_mse/Assumption_in_Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  assumptio to use linear regression
#
#
#  1. linear reln -> if jitne xi unka graph with y shoud be linear (linear means ki if ek line possible uske feature kar sake )
#
#
# 2. Multicolinearity -> if x1 change so iska impact kisi aur feature pe ni padna chaiye
#
# why : y=b+wx1+w2x2 jab grad cal toh jab w1 ka cal toh maante ki w2 x2 constant hai but if dono x1 x2 connected toh yeprinciple bhi break as x1 ke change se x2 m ifferent
#
# isko nukalne ka tarika hai

# %%
import pandas as pd
import numpy as np

# %%
x=np.random.randint(0,100,size=(50,3))
x=pd.DataFrame(df,columns=['f1','f2','f3'])

# %%
#multicoinearity find

from statsmodels.stats.outliers_influence import variance_inflation_factor

vif=[]

for i in range(x.shape[1]):
  vif.append(variance_inflation_factor(x,i))

pd.DataFrame({'vif':vif},index=x.columns)


#secnond mein heatmap bana le feature ke bich uke bich colinearity kam hona chaoye
# Out:
#          vif
# f1  2.949403
# f2  2.229929
# f3  2.872167

# %% [markdown]
# 3. Residual should be ploted normal ->
# jo difference ayega loss ka ya ypred-ytrue
#
# uko kde se plot toh vo normal dist hona chaoye
#
# ya q-q plotbhi kar sakte ho

# %% [markdown]
# 4. homosedasticity -> plt.scatter karke plot toh jo graph vo funnel type ni aana chaiye
# video dekh le

# %% [markdown]
# 5 autocorrelation of residual-> residual ko scatter plot toh koi pattern ni banna chaye it should be random like solpe ya hill type ko pattern ni aana chaiye
