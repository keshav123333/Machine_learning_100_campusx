# %% [markdown]
# <a href="https://colab.research.google.com/github/keshav123333/Machine_learning_100_campusx/blob/main/SVM/SVM%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #support vector machine
#
# iska video dekh bhai
#
#
#
# benfit-:
#
# 1> roboust to outlier
# 2> non linear data can be classified too
#
# 3>

# %%
from sklearn.svm import SVC

#ye jab linear data hai

# %%
# ab maan non linear hai data toh do teen option hot kernel set kar sakte hai hum apne hisab se iske liye sigmoid ,poly , rbf ye tranformation
#laga dete hai hum apne data pe and vo classify kar pate


model1=SVC(kernel="rbf")
model3=SVC(kernel="poly",degree=2)
model2=SVC(kernel="sigmoid")
